# %%
import seaborn as sns
import matplotlib.pyplot as plt
import json
import logging
import pandas as pd

d = {'0': 'Onderwijs',
 '1': 'Burgerrechten en vrijheden',
 '2': 'Justitie, Rechtspraak, Criminaliteit',
 '3': 'Defensie',
 '4': 'Gezondheid',
 '5': 'Gemeenschapsontwikkeling, huisvestingsbeleid en stedelijke planning',
 '6': 'Functioneren democratie en openbaar bestuur',
 '7': 'Macro-economie en belastingen',
 '8': 'Buitenlandse zaken en ontwikkelingssamenwerking',
 '9': 'Ondernemingen, Bankwezen en binnenlandse handel ',
 '10': 'Arbeid',
 '11': 'Verkeer en vervoer',
 '12': 'Overige',
 '13': 'sociale Zaken',
 '14': 'Immigratie en integratie',
 '15': 'Landbouw en Visserij',
 '16': 'Energiebeleid',
 '17': 'Milieu',
 '18': 'Wetenschappelijk onderzoek, technologie en communicatie'}


logger = logging.getLogger()
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)

class plot_accuracy_precision_recall():

    def __init__(self, path_to_data, path_to_output, sample):
        self.path_to_data = path_to_data
        self.path_to_output = path_to_output
        self.sample = sample
        with open('../resources/topic_translation') as handle:
               self.translator = json.loads(handle.read())
  #      with open('../resources/numbers_to_topic.json') as handle:
   #            self.translator_numeric = json.loads(handle.read())

    def get_data_dictionary(self):
         # getting Dictionary Approach Data
        fname = '{}precision_recall_f1score_dictionary_stemmed{}.json'.format(self.path_to_data, self.sample)
        logger.info(fname)

        with open(fname) as handle:
            dictdump =  json.loads(handle.read())

        df = pd.DataFrame.from_dict(dictdump).transpose()
        df['classifier'] = 'Albaugh et al. (Dictionary) - stemmed'

        fname_notstemmed = '{}precision_recall_f1score_dictionary_not_stemmed{}.json'.format(self.path_to_data, self.sample)
        logger.info(fname_notstemmed)

        with open(fname_notstemmed) as handle:
            dictdump =  json.loads(handle.read())

        df2 = pd.DataFrame.from_dict(dictdump).transpose()
        df2['classifier'] = 'Albaugh et al. - not stemmed'

        df = pd.concat([df, df2])
        df.rename(columns={0 :'precision',  1 :'recall', 2 :'f1-score'}, inplace=True)
        df.rename(index=self.translator, inplace=True)
        df['approach'] = 'Dictionary Approach'
        return df


    def get_data_sml(self, vect):
        fname_sml = '{}sml_vectorizers_final/SML_precision_recall_f1score_text_cleaned_{}_{}.json'.format(self.path_to_data, self.sample, vect)
        fname_sml= fname_sml
        with open(fname_sml) as handle:
            class_report =  json.loads(handle.read())

        one, two, three, four = class_report
        print(four)
        one = pd.DataFrame(one).transpose()
        one['classifier'] = "Passive Agressive"
        logging.info("Results Gridsearch Passive Agressive: \n\nC: {} \nfit intercept: {} \nmax_iter: {}  \nloss: {}"
              .format(one['clf__C'][one.index=='best estimators:'] [0] ,
                      one['clf__fit_intercept'][one.index=='best estimators:'][0] ,
                      one['clf__max_iter'][one.index=='best estimators:'] [0] ,
                      one['clf__loss'][one.index=='best estimators:'][0]  )  )


        two = pd.DataFrame(two).transpose()
        two['classifier'] = "Stochastic Gradient Descent (SGD)"

        logging.info("Results Gridsearch SGD Classifier: \n\nAlpha: {} \nmax iter: {} \npenalty: {} \n\n."
              .format(two['clf__alpha'][two.index=='best estimators:'] [0] ,
                    two['clf__max_iter'][two.index=='best estimators:'][0] ,
                    two['clf__penalty'][two.index=='best estimators:'][0]) )

        three = pd.DataFrame(three).transpose()
        three['classifier'] = "Support Vector Machines (SVM)"

        logging.info("Results Gridsearch SVM Classifier: \n\nC: {} \ngamma: {} \nkernel: {} \n\n."
                      .format(three['clf__C'][three.index=='best estimators:'] [0] ,
                              three['clf__gamma'][three.index=='best estimators:'] [0] ,
                              three['clf__kernel'][three.index=='best estimators:'] [0] ))

        four = pd.DataFrame(four).transpose()
        four['classifier'] = "ExtraTrees"

        logging.info("Results Gridsearch ExtraTrees: \n\nMax features:{}".format(four['clf__max_features'][four.index=='best estimators:'] [0]  ))

        df_sml = pd.concat([one, two, three, four])
        df_sml = df_sml[['precision', 'recall', 'f1-score', 'classifier']]
        df_sml.drop(['best estimators:', 'classifier:'], inplace = True)
        #df_sml['approach'] = 'SML'
        df_sml.rename(index=self.translator, inplace=True)
        return df_sml

    def combine_datasets(self):
        df1 = self.get_data_dictionary()
        df2 = self.get_data_sml(vect='w2v_tfidf')
        df2['approach'] = 'w2v tfidf'
        df3 = self.get_data_sml(vect='tfidf')
        df3['approach'] = 'tfidf'
        df4 = self.get_data_sml(vect='w2v_count')
        df4['approach'] = 'w2v count'
        df5 = self.get_data_sml(vect='count')
        df5['approach'] = 'count'
        df = pd.concat([df1, df2, df3, df4, df5])
        df.rename(index={'Accuracy': 'Average'}, inplace=True)
        df['Policy topic'] = df.index

        #df.replace({'weighted avg': 'Accuracy'}, inplace=True)
       # df.drop(['macro avg', 'Average'], inplace = True)
        return df

a = plot_accuracy_precision_recall(path_to_data = '../output/', path_to_output = '../tables/', sample ='RPA_sample')
df = a.combine_datasets()


def get_figure_and_save():
    myanalyzer = plot_accuracy_precision_recall(path_to_data = '../output/', path_to_output = '../tables/', sample ='RPA_sample')
    df = myanalyzer.combine_datasets()
    fname = '{}classification_topics'.format('../figures/')

    df['classifier + vectorizer'] = df['classifier'].astype(str) + " ~ " + df['approach'].astype(str)
    accuracy = df[df['Policy topic'] == 'Average']
    approach = accuracy["approach"]
    colour = ['whitesmoke' if x=='w2v tfidf' else 'dimgray' if x== 'w2v count' else 'black' if x== 'count' else 'silver' if x== 'tfidf' else 'white' for x in approach ]

    final_recode = {'Albaugh et al. - not stemmed ~ Dictionary Approach' : 'Albaugh et al. - not stemmed (dictionary)' ,
     'Albaugh et al. (Dictionary) - stemmed ~ Dictionary Approach' : 'Albaugh et al. - stemmed (dictionary)' ,
     'Support Vector Machines (SVM) ~ w2v count': 'SVM count embedding' ,
     'Support Vector Machines (SVM) ~ w2v tfidf' : 'SVM tfidf embedding' ,
     'ExtraTrees ~ count' : 'ET count',
     'ExtraTrees ~ tfidf' : 'ET tfidf',
     'ExtraTrees ~ w2v count' : 'ET count embedding',
     'Support Vector Machines (SVM) ~ tfidf' : 'SVM tfidf',
     'Support Vector Machines (SVM) ~ count' :  'SVM count',
     'ExtraTrees ~ w2v tfidf' :  'ET tfidf embedding',
     'Passive Agressive ~ tfidf' :  'PA tfidf',
     'Passive Agressive ~ count' :  'PA count',
     'Passive Agressive ~ w2v count' :  'PA count embedding',
     'Passive Agressive ~ w2v tfidf' :  'PA tfidf embedding',
     'Stochastic Gradient Descent (SGD) ~ count' :  'SGD count',
     'Stochastic Gradient Descent (SGD) ~ w2v count' : 'SGD count embedding',
     'Stochastic Gradient Descent (SGD) ~ tfidf' : 'SGD tfidf',
     'Stochastic Gradient Descent (SGD) ~ w2v tfidf' : 'SGD tfidf embedding'}

    df['classifier_updated'] = df['classifier + vectorizer'].map(final_recode)
    print(df['classifier_updated'] )
    f, ax = plt.subplots(figsize=(6,10))
    sns.set_context('talk')
    sns.set(style="whitegrid")

    order = ['Albaugh et al. - stemmed (dictionary)', 'Albaugh et al. - not stemmed (dictionary)',  'SVM tfidf', 'SVM tfidf embedding', 'SVM count', 'SVM count embedding', 'PA tfidf', 'PA tfidf embedding', 'PA count', 'PA count embedding', 'SGD tfidf', 'SGD tfidf embedding', 'SGD count', 'SGD count embedding', 'ET tfidf', 'ET tfidf embedding', 'ET count', 'ET count embedding']

    ax = sns.barplot(y="classifier_updated", x="f1-score",edgecolor=".4", palette=colour, order =order, data=df[df['Policy topic'] == 'Average'])
    ax = sns.set_style("white")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.title(None)
    plt.ylabel(None)
    plt.xlabel(None)
    plt.savefig(fname, bbox_inches = 'tight')
    print('Saved figure as: {}'.format(fname))

    sorterIndex = dict(zip(order,range(len(order))))
    # Generate a rank column that will be used to sort
    # the dataframe numerically
    df['Tm_Rank'] = df['classifier_updated'].map(sorterIndex)
    df.sort_values(['Policy topic','Tm_Rank'], inplace=True)
    df.to_csv('../output/weighted-f1-all_topics.csv')
    
    df = df[df['Policy topic'].isin(['Average'])]
    df.to_csv('../output/weigthed-f1-average-topics.csv')

get_figure_and_save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-84-26dc5790573d> in <module>
#     131         return df
#     132
# --> 133 a = plot_accuracy_precision_recall(path_to_data = '../output/', path_to_output = '../tables/', sample ='RPA_sample')
#     134 df = a.combine_datasets()
#     135
#
# <ipython-input-84-26dc5790573d> in __init__(self, path_to_data, path_to_output, sample)
#      36         self.path_to_output = path_to_output
#      37         self.sample = sample
# ---> 38         with open('../resources/topic_translation') as handle:
#      39                self.translator = json.loads(handle.read())
#      40   #      with open('../resources/numbers_to_topic.json') as handle:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../resources/topic_translation'

# %%
# Out:
# 2020-11-23 16:15:25,430 : INFO : output/precision_recall_f1score_dictionary_stemmedRPA_sample.json
# 2020-11-23 16:15:25,438 : INFO : output/precision_recall_f1score_dictionary_not_stemmedRPA_sample.json
# 2020-11-23 16:15:25,472 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: False
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:25,490 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: elasticnet
#
# .
# 2020-11-23 16:15:25,505 : INFO : Results Gridsearch SVM Classifier:
#
# C: 10
# gamma: 0.001
# kernel: rbf
#
# .
# 2020-11-23 16:15:25,520 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:109: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# 2020-11-23 16:15:25,568 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.5
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:25,601 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.001
# max iter: 30
# penalty: l2
#
# .
# 2020-11-23 16:15:25,617 : INFO : Results Gridsearch SVM Classifier:
#
# C: 10
# gamma: 0.001
# kernel: linear
#
# .
# 2020-11-23 16:15:25,637 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# {'Functioneren democratie en openbaar bestuur': {'precision': 0.6790123456790124, 'recall': 0.4700854700854701, 'f1-score': 0.5555555555555555, 'support': 117}, 'weighted avg': {'precision': 0.5317212128477621, 'recall': 0.49466192170818507, 'f1-score': 0.5043006779234309, 'support': 562}, 'Gezondheid': {'precision': 0.6984126984126984, 'recall': 0.6875, 'f1-score': 0.6929133858267716, 'support': 64}, 'Defensie': {'precision': 0.3076923076923077, 'recall': 0.5, 'f1-score': 0.380952380952381, 'support': 16}, 'sociale Zaken': {'precision': 0.14285714285714285, 'recall': 0.6, 'f1-score': 0.23076923076923073, 'support': 5}, 'Milieu': {'precision': 0.18181818181818182, 'recall': 0.3076923076923077, 'f1-score': 0.2285714285714286, 'support': 13}, 'best estimators:': {'clf__max_features': 'sqrt'}, 'Overige': {'precision': 0.5462184873949579, 'recall': 0.5, 'f1-score': 0.5220883534136547, 'support': 130}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'precision': 0.40476190476190477, 'recall': 0.4722222222222222, 'f1-score': 0.4358974358974359, 'support': 36}, 'Immigratie en integratie': {'precision': 0.38095238095238093, 'recall': 0.5714285714285714, 'f1-score': 0.4571428571428571, 'support': 14}, 'Onderwijs': {'precision': 0.3888888888888889, 'recall': 0.6363636363636364, 'f1-score': 0.4827586206896552, 'support': 11}, 'classifier:': 'ET', 'Arbeid': {'precision': 0.2, 'recall': 0.2, 'f1-score': 0.20000000000000004, 'support': 15}, 'micro avg': {'precision': 0.49466192170818507, 'recall': 0.49466192170818507, 'f1-score': 0.49466192170818507, 'support': 562}, 'Justitie, Rechtspraak, Criminaliteit': {'precision': 0.576271186440678, 'recall': 0.5074626865671642, 'f1-score': 0.5396825396825398, 'support': 67}, 'Verkeer en vervoer': {'precision': 0.5882352941176471, 'recall': 0.5882352941176471, 'f1-score': 0.5882352941176471, 'support': 34}, 'macro avg': {'precision': 0.39860106690449004, 'recall': 0.48060644203407277, 'f1-score': 0.41777519977891936, 'support': 562}, 'Burgerrechten en vrijheden': {'precision': 0.25, 'recall': 0.1875, 'f1-score': 0.21428571428571427, 'support': 32}, 'Ondernemingen, Bankwezen en binnenlandse handel ': {'precision': 0.23529411764705882, 'recall': 0.5, 'f1-score': 0.31999999999999995, 'support': 8}}
# {'Buitenlandse zaken en ontwikkelingssamenwerking': {'recall': 0.4, 'f1-score': 0.3902439024390244, 'support': 40, 'precision': 0.38095238095238093}, 'Ondernemingen, Bankwezen en binnenlandse handel ': {'recall': 0.5, 'f1-score': 0.31999999999999995, 'support': 8, 'precision': 0.23529411764705882}, 'best estimators:': {'clf__max_features': 'sqrt'}, 'Defensie': {'recall': 0.5294117647058824, 'f1-score': 0.41860465116279066, 'support': 17, 'precision': 0.34615384615384615}, 'sociale Zaken': {'recall': 1.0, 'f1-score': 0.0909090909090909, 'support': 1, 'precision': 0.047619047619047616}, 'Verkeer en vervoer': {'recall': 0.52, 'f1-score': 0.4406779661016949, 'support': 25, 'precision': 0.38235294117647056}, 'Immigratie en integratie': {'recall': 0.4, 'f1-score': 0.25806451612903225, 'support': 10, 'precision': 0.19047619047619047}, 'classifier:': 'ET', 'Burgerrechten en vrijheden': {'recall': 0.23809523809523808, 'f1-score': 0.22222222222222224, 'support': 21, 'precision': 0.20833333333333334}, 'Milieu': {'recall': 0.4, 'f1-score': 0.25000000000000006, 'support': 10, 'precision': 0.18181818181818182}, 'Arbeid': {'recall': 0.07692307692307693, 'f1-score': 0.07142857142857144, 'support': 13, 'precision': 0.06666666666666667}, 'weighted avg': {'recall': 0.4288256227758007, 'f1-score': 0.43995035187192255, 'support': 562, 'precision': 0.5077473744295491}, 'micro avg': {'recall': 0.4288256227758007, 'f1-score': 0.42882562277580066, 'support': 562, 'precision': 0.4288256227758007}, 'Functioneren democratie en openbaar bestuur': {'recall': 0.33714285714285713, 'f1-score': 0.4609375, 'support': 175, 'precision': 0.7283950617283951}, 'Justitie, Rechtspraak, Criminaliteit': {'recall': 0.5625, 'f1-score': 0.5046728971962616, 'support': 48, 'precision': 0.4576271186440678}, 'Gezondheid': {'recall': 0.6607142857142857, 'f1-score': 0.6218487394957983, 'support': 56, 'precision': 0.5873015873015873}, 'macro avg': {'recall': 0.49460920176060885, 'f1-score': 0.3621158574654135, 'support': 562, 'precision': 0.3359152192301554}, 'Overige': {'recall': 0.4108527131782946, 'f1-score': 0.4274193548387097, 'support': 129, 'precision': 0.44537815126050423}, 'Onderwijs': {'recall': 0.8888888888888888, 'f1-score': 0.5925925925925926, 'support': 9, 'precision': 0.4444444444444444}}
# 2020-11-23 16:15:25,686 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:25,702 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: elasticnet
#
# .
# 2020-11-23 16:15:25,746 : INFO : Results Gridsearch SVM Classifier:
#
# C: 100
# gamma: 0.0001
# kernel: rbf
#
# .
# 2020-11-23 16:15:25,759 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# 2020-11-23 16:15:25,828 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: True
# max_iter: 10
# loss: hinge
# {'Arbeid': {'recall': 0.2222222222222222, 'support': 18, 'f1-score': 0.2424242424242424, 'precision': 0.26666666666666666}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'recall': 0.45, 'support': 40, 'f1-score': 0.4390243902439024, 'precision': 0.42857142857142855}, 'weighted avg': {'recall': 0.48398576512455516, 'support': 562, 'f1-score': 0.4964645250211371, 'precision': 0.5299449419150222}, 'Milieu': {'recall': 0.3333333333333333, 'support': 15, 'f1-score': 0.27027027027027023, 'precision': 0.22727272727272727}, 'micro avg': {'recall': 0.48398576512455516, 'support': 562, 'f1-score': 0.48398576512455516, 'precision': 0.48398576512455516}, 'sociale Zaken': {'recall': 0.42857142857142855, 'support': 7, 'f1-score': 0.21428571428571427, 'precision': 0.14285714285714285}, 'Defensie': {'recall': 0.3333333333333333, 'support': 12, 'f1-score': 0.21052631578947367, 'precision': 0.15384615384615385}, 'Verkeer en vervoer': {'recall': 0.5384615384615384, 'support
.4827586206896551}, 'best estimators:': {'clf__max_features': 'auto'}, 'Defensie': {'precision': 0.19230769230769232, 'support': 9, 'recall': 0.5555555555555556, 'f1-score': 0.28571428571428575}, 'Immigratie en integratie': {'precision': 0.42857142857142855, 'support': 15, 'recall': 0.6, 'f1-score': 0.5}, 'Onderwijs': {'precision': 0.5, 'support': 17, 'recall': 0.5294117647058824, 'f1-score': 0.5142857142857143}}
# 2020-11-23 16:15:25,904 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: l2
#
# .
# 2020-11-23 16:15:25,921 : INFO : Results Gridsearch SVM Classifier:
#
# C: 1000
# gamma: 0.0001
# kernel: rbf
#
# .
# 2020-11-23 16:15:25,937 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:auto

# %%
#myanalyzer = plot_accuracy_precision_recall(path_to_data = 'output/', path_to_output = 'tables/', sample ='RPA_sample')
#df = myanalyzer.combine_datasets()
#df[df['Policy topic'] == 'Accuracy']
#df
# Out:
# 2020-11-23 16:10:25,294 : INFO : output/precision_recall_f1score_dictionary_stemmedRPA_sample.json
# 2020-11-23 16:10:25,305 : INFO : output/precision_recall_f1score_dictionary_not_stemmedRPA_sample.json
# 2020-11-23 16:10:25,340 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: False
# max_iter: 10
# loss: hinge
# 2020-11-23 16:10:25,354 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: elasticnet
#
# .
# 2020-11-23 16:10:25,370 : INFO : Results Gridsearch SVM Classifier:
#
# C: 10
# gamma: 0.001
# kernel: rbf
#
# .
# 2020-11-23 16:10:25,387 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:109: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# 2020-11-23 16:10:25,443 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.5
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:10:25,455 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.001
# max iter: 30
# penalty: l2
#
# .
# 2020-11-23 16:10:25,485 : INFO : Results Gridsearch SVM Classifier:
#
# C: 10
# gamma: 0.001
# kernel: linear
#
# .
# 2020-11-23 16:10:25,500 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# {'Functioneren democratie en openbaar bestuur': {'precision': 0.6790123456790124, 'recall': 0.4700854700854701, 'f1-score': 0.5555555555555555, 'support': 117}, 'weighted avg': {'precision': 0.5317212128477621, 'recall': 0.49466192170818507, 'f1-score': 0.5043006779234309, 'support': 562}, 'Gezondheid': {'precision': 0.6984126984126984, 'recall': 0.6875, 'f1-score': 0.6929133858267716, 'support': 64}, 'Defensie': {'precision': 0.3076923076923077, 'recall': 0.5, 'f1-score': 0.380952380952381, 'support': 16}, 'sociale Zaken': {'precision': 0.14285714285714285, 'recall': 0.6, 'f1-score': 0.23076923076923073, 'support': 5}, 'Milieu': {'precision': 0.18181818181818182, 'recall': 0.3076923076923077, 'f1-score': 0.2285714285714286, 'support': 13}, 'best estimators:': {'clf__max_features': 'sqrt'}, 'Overige': {'precision': 0.5462184873949579, 'recall': 0.5, 'f1-score': 0.5220883534136547, 'support': 130}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'precision': 0.40476190476190477, 'recall': 0.4722222222222222, 'f1-score': 0.4358974358974359, 'support': 36}, 'Immigratie en integratie': {'precision': 0.38095238095238093, 'recall': 0.5714285714285714, 'f1-score': 0.4571428571428571, 'support': 14}, '
# {'Arbeid': {'recall': 0.2222222222222222, 'support': 18, 'f1-score': 0.2424242424242424, 'precision': 0.26666666666666666}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'recall': 0.45, 'support': 40, 'f1-score': 0.4390243902439024, 'precision': 0.42857142857142855}, 'weighted avg': {'recall': 0.48398576512455516, 'support': 562, 'f1-score': 0.4964645250211371, 'precision': 0.5299449419150222}, 'Milieu': {'recall': 0.3333333333333333, 'support': 15, 'f1-score': 0.27027027027027023, 'precision': 0.22727272727272727}, 'micro avg': {'recall': 0.48398576512455516, 'support': 562, 'f1-score': 0.48398576512455516, 'precision': 0.48398576512455516}, 'sociale Zaken': {'recall': 0.42857142857142855, 'support': 7, 'f1-score': 0.21428571428571427, 'precision': 0.14285714285714285}, 'Defensie': {'recall': 0.3333333333333333, 'support': 12, 'f1-score': 0.21052631578947367, 'precision': 0.15384615384615385}, 'Verkeer en vervoer': {'recall': 0.5384615384615384, 'support': 26, 'f1-score': 0.4666666666666667, 'precision': 0.4117647058823529}, 'Onderwijs': {'recall': 0.46153846153846156, 'support': 13, 'f1-score': 0.3870967741935484, 'precision': 0.3333333333333333}, 'macro avg': {'recall': 0.4480836156792031, 'support': 562, 'f1-score': 0.40102440572051956, 'precision': 0.38674494139290233}, 'best estimators:': {'clf__max_features': 'sqrt'}, 'Functioneren democratie en openbaar bestuur': {'recall': 0.4566929133858268, 'support': 127, 'f1-score': 0.5576923076923078, 'precision': 0.7160493827160493}, 'Burgerrechten en vrijheden': {'recall': 0.36363636363636365, 'support': 22, 'f1-score': 0.34782608695652173, 'precision': 0.3333333333333333}, 'Justitie, Rechtspraak, Criminaliteit': {'recall': 0.4927536231884058, 'support': 69, 'f1-score': 0.53125, 'precision': 0.576271186440678}, 'Ondernemingen, Bankwezen en binnenlandse handel ': {'recall': 0.625, 'support': 8, 'f1-score': 0.4, 'precision': 0.29411764705882354}, 'Gezondheid': {'recall': 0.6833333333333333, 'support': 60, 'f1-score': 0.6666666666666666, 'precision': 0.6507936507936508}, 'classifier:': 'ET', 'Immigratie en integratie': {'recall': 0.3684210526315789, 'support': 19, 'f1-score': 0.35, 'precision': 0.3333333333333333}, 'Overige': {'recall': 0.5158730158730159, 'support': 126, 'f1-score': 0.5306122448979592, 'precision': 0.5462184873949579}}
# 2020-11-23 16:10:25,543 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:10:25,557 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: elasticnet
#
# .
# 2020-11-23 16:10:25,575 : INFO : Results Gridsearch SVM Classifier:
#
# C: 100
# gamma: 0.0001
# kernel: rbf
#
# .
# 2020-11-23 16:10:25,602 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# 2020-11-23 16:10:25,644 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:10:25,666 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: l2
#
# .
# 2020-11-23 16:10:25,678 : INFO : Results Gridsearch SVM Classifier:
#
# C: 1000
# gamma: 0.0001
# kernel: rbf
#
# .
# 2020-11-23 16:10:25,686 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:auto
# {'Milieu': {'precision': 0.18181818181818182, 'support': 12, 'recall': 0.3333333333333333, 'f1-score': 0.23529411764705885}, 'Ondernemingen, Bankwezen en binnenlandse handel ': {'precision': 0.23529411764705882, 'support': 7, 'recall': 0.5714285714285714, 'f1-score': 0.3333333333333333}, 'Justitie, Rechtspraak, Criminaliteit': {'precision': 0.5084745762711864, 'support': 62, 'recall': 0.4838709677419355, 'f1-score': 0.49586776859504134}, 'Verkeer en vervoer': {'precision': 0.4117647058823529, 'support': 25, 'recall': 0.56, 'f1-score': 0.4745762711864407}, 'classifier:': 'ET', 'Overige': {'precision': 0.44537815126050423, 'support': 125, 'recall': 0.424, 'f1-score': 0.4344262295081967}, 'Burgerrechten en vrijheden': {'precision': 0.125, 'support': 20, 'recall': 0.15, 'f1-score': 0.13636363636363635}, 'Arbeid': {'precision': 0.2, 'support': 17, 'recall': 0.17647058823529413, 'f1-score': 0.18750000000000003}, 'weighted avg': {'precision': 0.5034268386606982, 'support': 562, 'recall': 0.4430604982206406, 'f1-score': 0.45378656751061114}, 'sociale Zaken': {'precision': 0.047619047619047616, 'support': 1, 'recall': 1.0, 'f1-score': 0.0909090909090909}, 'macro avg': {'precision': 0.3610633938121713, 'support': 562, 'recall': 0.4950753313996407, 'f1-score': 0.3772325957828376}, 'micro avg': {'precision': 0.4430604982206406, 'support': 562, 'recall': 0.4430604982206406, 'f1-score': 0.4430604982206406}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'precision': 0.5, 'support': 54, 'recall': 0.3888888888888889, 'f1-score': 0.43750000000000006}, 'Gezondheid': {'precision': 0.5873015873015873, 'support': 47, 'recall': 0.7872340425531915, 'f1-score': 0.6727272727272727}, 'Functioneren democratie en openbaar bestuur': {'precision': 0.691358024691358, 'support': 151, 'recall': 0.3708609271523179, 'f1-score': 0.4827586206896551}, 'best estimators:': {'clf__max_features': 'auto'}, 'Defensie': {'precision': 0.19230769230769232, 'support': 9, 'recall': 0.5555555555555556, 'f1-score': 0.28571428571428575}, 'Immigratie en integratie': {'precision': 0.42857142857142855, 'support': 15, 'recall': 0.6, 'f1-score': 0.5}, 'Onderwijs': {'precision': 0.5, 'support': 17, 'recall': 0.5294117647058824, 'f1-score': 0.5142857142857143}}
#                              precision     recall   f1-score  \
# Governmental operations       0.461538  0.0992908   0.163424
# Education                     0.385135   0.575758   0.461538
# Civil rights                  0.352941  0.0361446  0.0655738
# Law & crime                   0.447853   0.257042   0.326622
# Banking, finance, & commerce  0.294118   0.210526   0.245399
# ...                                ...        ...        ...
# Health                        0.587302   0.787234   0.672727
# Governmental operations       0.691358   0.370861   0.482759
# Defense                       0.192308   0.555556   0.285714
# Immigration & integration     0.428571        0.6        0.5
# Education                          0.5   0.529412   0.514286
#
#                                                          classifier  \
# Governmental operations       Albaugh et al. (Dictionary) - stemmed
# Education                     Albaugh et al. (Dictionary) - stemmed
# Civil rights                  Albaugh et al. (Dictionary) - stemmed
# Law & crime                   Albaugh et al. (Dictionary) - stemmed
# Banking, finance, & commerce  Albaugh et al. (Dictionary) - stemmed
# ...                                                             ...
# Health                                                   ExtraTrees
# Governmental operations                                  ExtraTrees
# Defense                                                  ExtraTrees
# Immigration & integration                                ExtraTrees
# Education                                                ExtraTrees
#
#                                          approach  \
# Governmental operations       Dictionary Approach
# Education                     Dictionary Approach
# Civil rights                  Dictionary Approach
# Law & crime                   Dictionary Approach
# Banking, finance, & commerce  Dictionary Approach
# ...                                           ...
# Health                                      count
# Governmental operations                     count
# Defense                                     count
# Immigration & integration                   count
# Education                                   count
#
#                                               Policy topic
# Governmental operations            Governmental operations
# Education                                        Education
# Civil rights                                  Civil rights
# Law & crime                                    Law & crime
# Banking, finance, & commerce  Banking, finance, & commerce
# ...                                                    ...
# Health                                              Health
# Governmental operations            Governmental operations
# Defense                                            Defense
# Immigration & integration        Immigration & integration
# Education                                        Education
#
# [302 rows x 6 columns]

# %%
# Out:
# 2020-11-23 16:15:28,445 : INFO : output/precision_recall_f1score_dictionary_stemmedRPA_sample.json
# 2020-11-23 16:15:28,453 : INFO : output/precision_recall_f1score_dictionary_not_stemmedRPA_sample.json
# 2020-11-23 16:15:28,483 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: False
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:28,514 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: elasticnet
#
# .
# 2020-11-23 16:15:28,534 : INFO : Results Gridsearch SVM Classifier:
#
# C: 10
# gamma: 0.001
# kernel: rbf
#
# .
# 2020-11-23 16:15:28,558 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:109: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# 2020-11-23 16:15:28,618 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.5
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:28,625 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.001
# max iter: 30
# penalty: l2
#
# .
# 2020-11-23 16:15:28,632 : INFO : Results Gridsearch SVM Classifier:
#
# C: 10
# gamma: 0.001
# kernel: linear
#
# .
# 2020-11-23 16:15:28,643 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# {'Functioneren democratie en openbaar bestuur': {'precision': 0.6790123456790124, 'recall': 0.4700854700854701, 'f1-score': 0.5555555555555555, 'support': 117}, 'weighted avg': {'precision': 0.5317212128477621, 'recall': 0.49466192170818507, 'f1-score': 0.5043006779234309, 'support': 562}, 'Gezondheid': {'precision': 0.6984126984126984, 'recall': 0.6875, 'f1-score': 0.6929133858267716, 'support': 64}, 'Defensie': {'precision': 0.3076923076923077, 'recall': 0.5, 'f1-score': 0.380952380952381, 'support': 16}, 'sociale Zaken': {'precision': 0.14285714285714285, 'recall': 0.6, 'f1-score': 0.23076923076923073, 'support': 5}, 'Milieu': {'precision': 0.18181818181818182, 'recall': 0.3076923076923077, 'f1-score': 0.2285714285714286, 'support': 13}, 'best estimators:': {'clf__max_features': 'sqrt'}, 'Overige': {'precision': 0.5462184873949579, 'recall': 0.5, 'f1-score': 0.5220883534136547, 'support': 130}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'precision': 0.40476190476190477, 'recall': 0.4722222222222222, 'f1-score': 0.4358974358974359, 'support': 36}, 'Immigratie en integratie': {'precision': 0.38095238095238093, 'recall': 0.5714285714285714, 'f1-score': 0.4571428571428571, 'support': 14}, 'Onderwijs': {
# {'Arbeid': {'recall': 0.2222222222222222, 'support': 18, 'f1-score': 0.2424242424242424, 'precision': 0.26666666666666666}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'recall': 0.45, 'support': 40, 'f1-score': 0.4390243902439024, 'precision': 0.42857142857142855}, 'weighted avg': {'recall': 0.48398576512455516, 'support': 562, 'f1-score': 0.4964645250211371, 'precision': 0.5299449419150222}, 'Milieu': {'recall': 0.3333333333333333, 'support': 15, 'f1-score': 0.27027027027027023, 'precision': 0.22727272727272727}, 'micro avg': {'recall': 0.48398576512455516, 'support': 562, 'f1-score': 0.48398576512455516, 'precision': 0.48398576512455516}, 'sociale Zaken': {'recall': 0.42857142857142855, 'support': 7, 'f1-score': 0.21428571428571427, 'precision': 0.14285714285714285}, 'Defensie': {'recall': 0.3333333333333333, 'support': 12, 'f1-score': 0.21052631578947367, 'precision': 0.15384615384615385}, 'Verkeer en vervoer': {'recall': 0.5384615384615384, 'support': 26, 'f1-score': 0.4666666666666667, 'precision': 0.4117647058823529}, 'Onderwijs': {'recall': 0.46153846153846156, 'support': 13, 'f1-score': 0.3870967741935484, 'precision': 0.3333333333333333}, 'macro avg': {'recall': 0.4480836156792031, 'support': 562, 'f1-score': 0.40102440572051956, 'precision': 0.38674494139290233}, 'best estimators:': {'clf__max_features': 'sqrt'}, 'Functioneren democratie en openbaar bestuur': {'recall': 0.4566929133858268, 'support': 127, 'f1-score': 0.5576923076923078, 'precision': 0.7160493827160493}, 'Burgerrechten en vrijheden': {'recall': 0.36363636363636365, 'support': 22, 'f1-score': 0.34782608695652173, 'precision': 0.3333333333333333}, 'Justitie, Rechtspraak, Criminaliteit': {'recall': 0.4927536231884058, 'support': 69, 'f1-score': 0.53125, 'precision': 0.576271186440678}, 'Ondernemingen, Bankwezen en binnenlandse handel ': {'recall': 0.625, 'support': 8, 'f1-score': 0.4, 'precision': 0.29411764705882354}, 'Gezondheid': {'recall': 0.6833333333333333, 'support': 60, 'f1-score': 0.6666666666666666, 'precision': 0.6507936507936508}, 'classifier:': 'ET', 'Immigratie en integratie': {'recall': 0.3684210526315789, 'support': 19, 'f1-score': 0.35, 'precision': 0.3333333333333333}, 'Overige': {'recall': 0.5158730158730159, 'support': 126, 'f1-score': 0.5306122448979592, 'precision': 0.5462184873949579}}
# 2020-11-23 16:15:28,717 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:28,739 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: elasticnet
#
# .
# 2020-11-23 16:15:28,763 : INFO : Results Gridsearch SVM Classifier:
#
# C: 100
# gamma: 0.0001
# kernel: rbf
#
# .
# 2020-11-23 16:15:28,775 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:sqrt
# 2020-11-23 16:15:28,816 : INFO : Results Gridsearch Passive Agressive:
#
# C: 0.01
# fit intercept: True
# max_iter: 10
# loss: hinge
# 2020-11-23 16:15:28,822 : INFO : Results Gridsearch SGD Classifier:
#
# Alpha: 0.01
# max iter: 20
# penalty: l2
#
# .
# 2020-11-23 16:15:28,831 : INFO : Results Gridsearch SVM Classifier:
#
# C: 1000
# gamma: 0.0001
# kernel: rbf
#
# .
# 2020-11-23 16:15:28,841 : INFO : Results Gridsearch ExtraTrees:
#
# Max features:auto
# 2020-11-23 16:15:28,991 : WARNING : No handles with labels found to put in legend.
# {'Milieu': {'precision': 0.18181818181818182, 'support': 12, 'recall': 0.3333333333333333, 'f1-score': 0.23529411764705885}, 'Ondernemingen, Bankwezen en binnenlandse handel ': {'precision': 0.23529411764705882, 'support': 7, 'recall': 0.5714285714285714, 'f1-score': 0.3333333333333333}, 'Justitie, Rechtspraak, Criminaliteit': {'precision': 0.5084745762711864, 'support': 62, 'recall': 0.4838709677419355, 'f1-score': 0.49586776859504134}, 'Verkeer en vervoer': {'precision': 0.4117647058823529, 'support': 25, 'recall': 0.56, 'f1-score': 0.4745762711864407}, 'classifier:': 'ET', 'Overige': {'precision': 0.44537815126050423, 'support': 125, 'recall': 0.424, 'f1-score': 0.4344262295081967}, 'Burgerrechten en vrijheden': {'precision': 0.125, 'support': 20, 'recall': 0.15, 'f1-score': 0.13636363636363635}, 'Arbeid': {'precision': 0.2, 'support': 17, 'recall': 0.17647058823529413, 'f1-score': 0.18750000000000003}, 'weighted avg': {'precision': 0.5034268386606982, 'support': 562, 'recall': 0.4430604982206406, 'f1-score': 0.45378656751061114}, 'sociale Zaken': {'precision': 0.047619047619047616, 'support': 1, 'recall': 1.0, 'f1-score': 0.0909090909090909}, 'macro avg': {'precision': 0.3610633938121713, 'support': 562, 'recall': 0.4950753313996407, 'f1-score': 0.3772325957828376}, 'micro avg': {'precision': 0.4430604982206406, 'support': 562, 'recall': 0.4430604982206406, 'f1-score': 0.4430604982206406}, 'Buitenlandse zaken en ontwikkelingssamenwerking': {'precision': 0.5, 'support': 54, 'recall': 0.3888888888888889, 'f1-score': 0.43750000000000006}, 'Gezondheid': {'precision': 0.5873015873015873, 'support': 47, 'recall': 0.7872340425531915, 'f1-score': 0.6727272727272727}, 'Functioneren democratie en openbaar bestuur': {'precision': 0.691358024691358, 'support': 151, 'recall': 0.3708609271523179, 'f1-score': 0.4827586206896551}, 'best estimators:': {'clf__max_features': 'auto'}, 'Defensie': {'precision': 0.19230769230769232, 'support': 9, 'recall': 0.5555555555555556, 'f1-score': 0.28571428571428575}, 'Immigratie en integratie': {'precision': 0.42857142857142855, 'support': 15, 'recall': 0.6, 'f1-score': 0.5}, 'Onderwijs': {'precision': 0.5, 'support': 17, 'recall': 0.5294117647058824, 'f1-score': 0.5142857142857143}}
# Governmental operations         Albaugh et al. - stemmed (dictionary)
# Education                       Albaugh et al. - stemmed (dictionary)
# Civil rights                    Albaugh et al. - stemmed (dictionary)
# Law & crime                     Albaugh et al. - stemmed (dictionary)
# Banking, finance, & commerce    Albaugh et al. - stemmed (dictionary)
#                                                 ...
# Health                                                       ET count
# Governmental operations                                      ET count
# Defense                                                      ET count
# Immigration & integration                                    ET count
# Education                                                    ET count
# Name: classifier_updated, Length: 302, dtype: object
# Saved figure as: figures/classification_topics
